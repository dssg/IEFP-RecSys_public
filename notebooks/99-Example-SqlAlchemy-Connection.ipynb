# %% [markdown]
# # SqlAlchemy

# %% [markdown]
# ## Imports

# %%
import os
import yaml
import pandas as pd
from urllib.parse import quote_plus  # PY2: from urllib import quote_plus
from sqlalchemy.engine import create_engine
from sqlalchemy.sql.expression import select
from sqlalchemy.sql.functions import func
from sqlalchemy.sql.schema import Table, MetaData

# %%
aws_cred = yaml.load(open("../conf/local/credentials.yml"), Loader=yaml.FullLoader)

# %% [markdown]
# ## SqlAlchemy connection

# %%
# Basic connection

conn_str = 'awsathena+rest://{aws_access_key_id}:{aws_secret_access_key}@athena.{region_name}.amazonaws.com:443/'\
           '{schema_name}?s3_staging_dir={s3_staging_dir}'
engine = create_engine(conn_str.format(
    aws_access_key_id=quote_plus(aws_cred['dssg']['aws_access_key_id']),
    aws_secret_access_key=quote_plus(aws_cred['dssg']['aws_secret_access_key']),
    region_name='eu-west-2',
    schema_name='default',
    s3_staging_dir=quote_plus('s3://iefp-unemployment/SIGAE/')))

# SQL query

query = "select * from sigae.emp_ofertas LIMIT 5;"
df = pd.read_sql_query(query, engine)

# %%
df.head()
# Out:
#     ano_mes tipo_movimento centro cnp ind_cnp a_tempo natureza_emprego  \
# 0  "201601"           "61"  "224"                   C                T
# 1  "201601"           "84"                          C                T
# 2  "201601"           "61"  "586"                   C                T
# 3  "201601"           "84"                          C                T
# 4  "201601"           "71"  "165"                   C                I
#
#   nr_meses idade_minima idade_maxima  ... processo_recup_empresas      cpp  \
# 0       12                            ...                       N  "51410"
# 1       12                            ...                       N  "51410"
# 2        6                            ...                       N  "92140"
# 3        6                            ...                       N  "92140"
# 4                                     ...                          "53220"
#
#   ind_cpp cpp_pretendida me2014 eao e_mais pais_residencia_estrang  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 99 columns):
# ano_mes                          5 non-null object
# tipo_movimento                   5 non-null object
# centro                           5 non-null object
# cnp                              5 non-null object
# ind_cnp                          5 non-null object
# a_tempo                          5 non-null object
# natureza_emprego                 5 non-null object
# nr_meses                         5 non-null object
# idade_minima                     5 non-null object
# idade_maxima                     5 non-null object
# habilitacoes_minima              5 non-null object
# habilitacoes_maximo              5 non-null object
# salario                          5 non-null object
# tipo_salario                     5 non-null object
# transporte_proprio               5 non-null object
# carta_conducao                   5 non-null object
# ...
